# %%
import pandas as pd
import sqlite3

# Path to the SQLite database
db_path = 'masterfile.db'

# Function to print table names and first few rows of each table
def print_db_contents():
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    
    # Get all table names
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()
    
    # Iterate through the tables and print the first few rows
    for table in tables:
        table_name = table[0]
        print(f"Table: {table_name}")
        df = pd.read_sql(f"SELECT * FROM {table_name} LIMIT 5", conn)
        print(df)
        print("\n")
    
    conn.close()

# Call the function to print the database contents
print_db_contents()
# Out:
# Table: final_file_extended_columns_HIT_HP
#                 product_name  mRd_minus  vRd_plus      c  cc   hh    h  \
# 0  HIT_HP-MVX-1812-16-100-35      -32.5     192.0  20/25  35  160  125
# 1  HIT_HP-MVX-1812-16-100-35      -65.6      70.0  20/25  35  160  125
# 2  HIT_HP-MVX-1812-16-100-35      -38.5     192.0  25/30  35  160  125
# 3  HIT_HP-MVX-1812-16-100-35      -71.6      73.9  25/30  35  160  125
# 4  HIT_HP-MVX-1812-16-100-35      -42.9     192.0  30/37  35  160  125
#
#    mrd_type  vrd_type Thickness Type   CSB  Width
# 0         1         1    HIT_HP  MVX  1812    100
# 1         2         2    HIT_HP  MVX  1812    100
# 2         1         1    HIT_HP  MVX  1812    100
# 3         2         2    HIT_HP  MVX  1812    100
# 4         1         1    HIT_HP  MVX  1812    100
#
#
# Table: final_file_extended_columns_HIT_SP
#                 product_name  mRd_minus  vRd_plus      c  cc   hh    h  \
# 0  HIT_SP-MVX-1812-16-100-35      -36.3     154.9  20/25  35  160  125
# 1  HIT_SP-MVX-1812-16-100-35      -65.6      44.6  20/25  35  160  125
# 2  HIT_SP-MVX-1812-16-100-35      -37.9     166.8  25/30  35  160  125
# 3  HIT_SP-MVX-1812-16-100-35      -71.6      47.1  25/30  35  160  125
# 4  HIT_SP-MVX-1812-16-100-35      -39.9     173.2  30/37  35  160  125
#
#    mrd_type  vrd_type Thickness Type   CSB  Width
# 0         1         1    HIT_SP  MVX  1812    100
# 1         2         2    HIT_SP  MVX  1812    100
# 2         1         1    HIT_SP  MVX  1812    100
# 3         2         2    HIT_SP  MVX  1812    100
# 4         1         1    HIT_SP  MVX  1812    100
#
#
# Table: Isokorb_Q_QT
#                          product_name    vRd vRd_plus vRd_minus
# 0  XT-QP-VV1-REI120-X80-H190-L300-5.0  ±34,5     34,5      34,5
# 1  XT-QP-VV2-REI120-X80-H190-L400-5.0  ±58,8     58,8      58,8
# 2  XT-QP-VV3-REI120-X80-H190-L500-5.0  ±68,9     68,9      68,9
# 3  XT-QP-VV4-REI120-X80-H200-L300-5.0  ±56,4     56,4      56,4
# 4  XT-QP-VV5-REI120-X80-H200-L400-5.0  ±68,9     68,9      68,9
#
#
# Table: updated_Isokorb_T_full_columns
#                                   product_name    mRd    vRd  mRd_plus  \
# 0    T-D-MM1-VV1-REI120-CV35-X80-H160-L500-6.0   ±7,4  ±17,4       7.4
# 1  T-D-MM1-VV1.2-REI120-CV35-X80-H160-L500-6.0  ±14,8  ±34,8      14.8
# 2    T-D-MM1-VV2-REI120-CV35-X80-H160-L500-6.0   ±7,1  ±26,1       7.1
# 3  T-D-MM1-VV2.2-REI120-CV35-X80-H160-L500-6.0  ±14,2  ±52,2      14.2
# 4    T-D-MM1-VV1-REI120-CV30-X80-H160-L500-6.0   ±7,9  ±17,4       7.9
#
#    mRd_minus  vRd_plus  vRd_minus       C Length Thickness Type M-type V-type  \
# 0        7.4      17.4       17.4  C25/30   L500         T    D    MM1  VV1.2
# 1       14.8      34.8       34.8  C25/30   L500         T    D    MM1  VV1.1
# 2        7.1      26.1       26.1  C25/30   L500         T    D    MM1  VV2.2
# 3       14.2      52.2       52.2  C25/30   L500         T    D    MM1  VV2.1
# 4        7.9      17.4       17.4  C25/30   L500         T    D    MM1  VV1.2
#
#   REI-type CV-type X-type Height Type Number
# 0   REI120    CV35    X80   H160         6.0
# 1   REI120    CV35    X80   H160         6.0
# 2   REI120    CV35    X80   H160         6.0
# 3   REI120    CV35    X80   H160         6.0
# 4   REI120    CV30    X80   H160         6.0
#
#
# Table: updated_Isokorb_XT_full_columns
#                                     product_name    mRd    vRd  mRd_plus  \
# 0  XT-D-MM1-VV1.2-REI120-CV35-X120-H160-L500-6.0  ±14,6  ±28,2      14.6
# 1    XT-D-MM1-VV2-REI120-CV35-X120-H160-L500-6.0   ±6,9  ±21,2       6.9
# 2  XT-D-MM1-VV2.2-REI120-CV35-X120-H160-L500-6.0  ±13,8  ±42,4      13.8
# 3  XT-D-MM1-VV1.2-REI120-CV50-X120-H200-L500-6.0  ±15,6  ±28,2      15.6
# 4    XT-D-MM1-VV2-REI120-CV50-X120-H200-L500-6.0   ±7,3  ±21,2       7.3
#
#    mRd_minus  vRd_plus  vRd_minus       C Length Thickness Type M-type V-type  \
# 0       14.6      28.2       28.2  C25/30   L500        XT    D    MM1  VV1.1
# 1        6.9      21.2       21.2  C25/30   L500        XT    D    MM1  VV2.2
# 2       13.8      42.4       42.4  C25/30   L500        XT    D    MM1  VV2.1
# 3       15.6      28.2       28.2  C25/30   L500        XT    D    MM1  VV1.1
# 4        7.3      21.2       21.2  C25/30   L500        XT    D    MM1  VV2.2
#
#   REI-type CV-type X-type Height Type Number
# 0   REI120    CV35   X120   H160         6.0
# 1   REI120    CV35   X120   H160         6.0
# 2   REI120    CV35   X120   H160         6.0
# 3   REI120    CV50   X120   H200         6.0
# 4   REI120    CV50   X120   H200         6.0
